# %% [markdown]
# <a href="https://colab.research.google.com/github/prof-nuduls/EE628HW/blob/main/EE628_HW_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.layers import Input, Dense
import matplotlib.pyplot as plt
from keras.models import Model

# this is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder = Model(input_img, decoded)
# this model maps an input to its encoded representation
encoder = Model(input_img, encoded)

# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(encoding_dim,))
# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))

autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)

epochs = [5, 10, 20, 30, 40, 50, 100]
for epoch in epochs:
  history = autoencoder.fit(x_train, x_train,
                  epochs=epoch,
                  batch_size=256,
                  shuffle=True,
                  validation_data=(x_test, x_test))
  # Plot training and validation losses
  plt.plot(history.history['loss'], label='Training Loss')
  plt.plot(history.history['val_loss'], label='Validation Loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()


  num_images = 10
  np.random.seed(42)
  random_test_images = np.random.randint(x_test.shape[0], size=num_images)

  encoded_imgs = encoder.predict(x_test)
  decoded_imgs = autoencoder.predict(x_test)

  plt.figure(figsize=(18, 4))

  for i, image_idx in enumerate(random_test_images):
      # plot original image
      ax = plt.subplot(3, num_images, i + 1)
      plt.imshow(x_test[image_idx].reshape(28, 28))
      plt.gray()
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)

      # plot encoded image
      ax = plt.subplot(3, num_images, num_images + i + 1)
      plt.imshow(encoded_imgs[image_idx].reshape(8, 4))
      plt.gray()
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)

      # plot reconstructed image
      ax = plt.subplot(3, num_images, 2*num_images + i + 1)
      plt.imshow(decoded_imgs[image_idx].reshape(28, 28))
      plt.gray()
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)
  plt.show()
# Out:
# (60000, 784)
# (10000, 784)
# Epoch 1/5
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6938 - val_loss: 0.6937
# Epoch 2/5
# 235/235 [==============================] - 2s 11ms/step - loss: 0.6936 - val_loss: 0.6935
# Epoch 3/5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6935 - val_loss: 0.6934
# Epoch 4/5
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6933 - val_loss: 0.6932
# Epoch 5/5
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6932 - val_loss: 0.6931
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 2ms/step
# Epoch 1/10
# 235/235 [==============================] - 5s 21ms/step - loss: 0.6930 - val_loss: 0.6929
# Epoch 2/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6929 - val_loss: 0.6928
# Epoch 3/10
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6927 - val_loss: 0.6927
# Epoch 4/10
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6926 - val_loss: 0.6925
# Epoch 5/10
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6924 - val_loss: 0.6924
# Epoch 6/10
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6923 - val_loss: 0.6922
# Epoch 7/10
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6921 - val_loss: 0.6921
# Epoch 8/10
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6920 - val_loss: 0.6919
# Epoch 9/10
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6919 - val_loss: 0.6918
# Epoch 10/10
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6917 - val_loss: 0.6916
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 2ms/step
# Epoch 1/20
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6916 - val_loss: 0.6915
# Epoch 2/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6914 - val_loss: 0.6913
# Epoch 3/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6913 - val_loss: 0.6912
# Epoch 4/20
# 235/235 [==============================] - 4s 19ms/step - loss: 0.6911 - val_loss: 0.6910
# Epoch 5/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6910 - val_loss: 0.6909
# Epoch 6/20
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6908 - val_loss: 0.6907
# Epoch 7/20
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6907 - val_loss: 0.6906
# Epoch 8/20
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6905 - val_loss: 0.6904
# Epoch 9/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6903 - val_loss: 0.6903
# Epoch 10/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6902 - val_loss: 0.6901
# Epoch 11/20
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6900 - val_loss: 0.6899
# Epoch 12/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6899 - val_loss: 0.6898
# Epoch 13/20
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6897 - val_loss: 0.6896
# Epoch 14/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6895 - val_loss: 0.6894
# Epoch 15/20
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6894 - val_loss: 0.6893
# Epoch 16/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6892 - val_loss: 0.6891
# Epoch 17/20
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6890 - val_loss: 0.6889
# Epoch 18/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6889 - val_loss: 0.6888
# Epoch 19/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6887 - val_loss: 0.6886
# Epoch 20/20
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6885 - val_loss: 0.6884
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 2ms/step
# Epoch 1/30
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6883 - val_loss: 0.6882
# Epoch 2/30
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6881 - val_loss: 0.6880
# Epoch 3/30
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6879 - val_loss: 0.6878
# Epoch 4/30
# 235/235 [==============================] - 3s 15ms/step - loss: 0.6877 - val_loss: 0.6876
# Epoch 5/30
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6875 - val_loss: 0.6874
# Epoch 6/30
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6873 - val_loss: 0.6872
# Epoch 7/30
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6871 - val_loss: 0.6870
# Epoch 8/30
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6869 - val_loss: 0.6868
# Epoch 9/30
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6867 - val_loss: 0.6866
# Epoch 10/30
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6865 - val_loss: 0.6864
# Epoch 11/30
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6863 - val_loss: 0.6861
# Epoch 12/30
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6860 - val_loss: 0.6859
# Epoch 13/30
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6858 - val_loss: 0.6857
# Epoch 14/30
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6856 - val_loss: 0.6854
# Epoch 15/30
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6853 - val_loss: 0.6852
# Epoch 16/30
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6851 - val_loss: 0.6849
# Epoch 17/30
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6848 - val_loss: 0.6847
# Epoch 18/30
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6845 - val_loss: 0.6844
# Epoch 19/30
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6843 - val_loss: 0.6841
# Epoch 20/30
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6840 - val_loss: 0.6838
# Epoch 21/30
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6837 - val_loss: 0.6835
# Epoch 22/30
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6834 - val_loss: 0.6832
# Epoch 23/30
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6831 - val_loss: 0.6829
# Epoch 24/30
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6828 - val_loss: 0.6826
# Epoch 25/30
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6825 - val_loss: 0.6823
# Epoch 26/30
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6822 - val_loss: 0.6820
# Epoch 27/30
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6818 - val_loss: 0.6816
# Epoch 28/30
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6815 - val_loss: 0.6813
# Epoch 29/30
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6812 - val_loss: 0.6809
# Epoch 30/30
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6808 - val_loss: 0.6806
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 2ms/step
# Epoch 1/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6804 - val_loss: 0.6802
# Epoch 2/40
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6800 - val_loss: 0.6798
# Epoch 3/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6797 - val_loss: 0.6794
# Epoch 4/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6793 - val_loss: 0.6790
# Epoch 5/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6788 - val_loss: 0.6786
# Epoch 6/40
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6784 - val_loss: 0.6781
# Epoch 7/40
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6780 - val_loss: 0.6777
# Epoch 8/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6775 - val_loss: 0.6772
# Epoch 9/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6771 - val_loss: 0.6767
# Epoch 10/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6766 - val_loss: 0.6763
# Epoch 11/40
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6761 - val_loss: 0.6758
# Epoch 12/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6756 - val_loss: 0.6752
# Epoch 13/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6751 - val_loss: 0.6747
# Epoch 14/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6745 - val_loss: 0.6742
# Epoch 15/40
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6740 - val_loss: 0.6736
# Epoch 16/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6734 - val_loss: 0.6730
# Epoch 17/40
# 235/235 [==============================] - 5s 21ms/step - loss: 0.6728 - val_loss: 0.6724
# Epoch 18/40
# 235/235 [==============================] - 5s 19ms/step - loss: 0.6722 - val_loss: 0.6718
# Epoch 19/40
# 235/235 [==============================] - 5s 21ms/step - loss: 0.6716 - val_loss: 0.6712
# Epoch 20/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6710 - val_loss: 0.6705
# Epoch 21/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6703 - val_loss: 0.6699
# Epoch 22/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6697 - val_loss: 0.6692
# Epoch 23/40
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6690 - val_loss: 0.6685
# Epoch 24/40
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6683 - val_loss: 0.6677
# Epoch 25/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6675 - val_loss: 0.6670
# Epoch 26/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6668 - val_loss: 0.6662
# Epoch 27/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6660 - val_loss: 0.6654
# Epoch 28/40
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6652 - val_loss: 0.6646
# Epoch 29/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6644 - val_loss: 0.6638
# Epoch 30/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6636 - val_loss: 0.6629
# Epoch 31/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6627 - val_loss: 0.6620
# Epoch 32/40
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6618 - val_loss: 0.6611
# Epoch 33/40
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6609 - val_loss: 0.6601
# Epoch 34/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6599 - val_loss: 0.6592
# Epoch 35/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6590 - val_loss: 0.6582
# Epoch 36/40
# 235/235 [==============================] - 3s 15ms/step - loss: 0.6580 - val_loss: 0.6572
# Epoch 37/40
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6569 - val_loss: 0.6561
# Epoch 38/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6559 - val_loss: 0.6550
# Epoch 39/40
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6548 - val_loss: 0.6539
# Epoch 40/40
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6537 - val_loss: 0.6528
# 313/313 [==============================] - 0s 2ms/step
# 313/313 [==============================] - 1s 2ms/step
# Epoch 1/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6525 - val_loss: 0.6516
# Epoch 2/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6514 - val_loss: 0.6504
# Epoch 3/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6502 - val_loss: 0.6492
# Epoch 4/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6489 - val_loss: 0.6479
# Epoch 5/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6477 - val_loss: 0.6466
# Epoch 6/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6464 - val_loss: 0.6453
# Epoch 7/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6450 - val_loss: 0.6439
# Epoch 8/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6436 - val_loss: 0.6425
# Epoch 9/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6422 - val_loss: 0.6410
# Epoch 10/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6408 - val_loss: 0.6395
# Epoch 11/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6393 - val_loss: 0.6380
# Epoch 12/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6378 - val_loss: 0.6365
# Epoch 13/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6362 - val_loss: 0.6349
# Epoch 14/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6346 - val_loss: 0.6332
# Epoch 15/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6330 - val_loss: 0.6316
# Epoch 16/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6313 - val_loss: 0.6299
# Epoch 17/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6296 - val_loss: 0.6281
# Epoch 18/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6279 - val_loss: 0.6263
# Epoch 19/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6261 - val_loss: 0.6245
# Epoch 20/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6242 - val_loss: 0.6226
# Epoch 21/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6224 - val_loss: 0.6207
# Epoch 22/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6204 - val_loss: 0.6187
# Epoch 23/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6185 - val_loss: 0.6167
# Epoch 24/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6165 - val_loss: 0.6147
# Epoch 25/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6144 - val_loss: 0.6126
# Epoch 26/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6124 - val_loss: 0.6104
# Epoch 27/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6102 - val_loss: 0.6083
# Epoch 28/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6081 - val_loss: 0.6061
# Epoch 29/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6058 - val_loss: 0.6038
# Epoch 30/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6036 - val_loss: 0.6015
# Epoch 31/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6013 - val_loss: 0.5992
# Epoch 32/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5990 - val_loss: 0.5968
# Epoch 33/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.5966 - val_loss: 0.5943
# Epoch 34/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.5942 - val_loss: 0.5919
# Epoch 35/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5917 - val_loss: 0.5894
# Epoch 36/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5892 - val_loss: 0.5868
# Epoch 37/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.5866 - val_loss: 0.5842
# Epoch 38/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.5841 - val_loss: 0.5816
# Epoch 39/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5814 - val_loss: 0.5789
# Epoch 40/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5788 - val_loss: 0.5762
# Epoch 41/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5761 - val_loss: 0.5735
# Epoch 42/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.5734 - val_loss: 0.5707
# Epoch 43/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.5706 - val_loss: 0.5679
# Epoch 44/50
# 235/235 [==============================] - 6s 26ms/step - loss: 0.5678 - val_loss: 0.5650
# Epoch 45/50
# 235/235 [==============================] - 4s 19ms/step - loss: 0.5649 - val_loss: 0.5621
# Epoch 46/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5621 - val_loss: 0.5592
# Epoch 47/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5592 - val_loss: 0.5563
# Epoch 48/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.5562 - val_loss: 0.5533
# Epoch 49/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.5533 - val_loss: 0.5503
# Epoch 50/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5503 - val_loss: 0.5472
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 2ms/step
# Epoch 1/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.5473 - val_loss: 0.5442
# Epoch 2/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.5442 - val_loss: 0.5411
# Epoch 3/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5412 - val_loss: 0.5380
# Epoch 4/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.5381 - val_loss: 0.5349
# Epoch 5/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.5350 - val_loss: 0.5317
# Epoch 6/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5318 - val_loss: 0.5286
# Epoch 7/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5287 - val_loss: 0.5254
# Epoch 8/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.5256 - val_loss: 0.5222
# Epoch 9/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.5224 - val_loss: 0.5190
# Epoch 10/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5192 - val_loss: 0.5158
# Epoch 11/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5160 - val_loss: 0.5126
# Epoch 12/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.5128 - val_loss: 0.5093
# Epoch 13/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.5096 - val_loss: 0.5061
# Epoch 14/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.5064 - val_loss: 0.5029
# Epoch 15/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.5032 - val_loss: 0.4996
# Epoch 16/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.5000 - val_loss: 0.4964
# Epoch 17/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.4968 - val_loss: 0.4932
# Epoch 18/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4936 - val_loss: 0.4899
# Epoch 19/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4904 - val_loss: 0.4867
# Epoch 20/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4872 - val_loss: 0.4835
# Epoch 21/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.4840 - val_loss: 0.4803
# Epoch 22/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4808 - val_loss: 0.4771
# Epoch 23/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4777 - val_loss: 0.4740
# Epoch 24/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4745 - val_loss: 0.4708
# Epoch 25/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.4714 - val_loss: 0.4677
# Epoch 26/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4683 - val_loss: 0.4646
# Epoch 27/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4652 - val_loss: 0.4615
# Epoch 28/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4621 - val_loss: 0.4584
# Epoch 29/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.4591 - val_loss: 0.4553
# Epoch 30/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.4561 - val_loss: 0.4523
# Epoch 31/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4531 - val_loss: 0.4493
# Epoch 32/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4501 - val_loss: 0.4464
# Epoch 33/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4472 - val_loss: 0.4434
# Epoch 34/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.4443 - val_loss: 0.4405
# Epoch 35/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4414 - val_loss: 0.4376
# Epoch 36/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4385 - val_loss: 0.4348
# Epoch 37/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4357 - val_loss: 0.4320
# Epoch 38/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.4329 - val_loss: 0.4292
# Epoch 39/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4302 - val_loss: 0.4265
# Epoch 40/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4274 - val_loss: 0.4238
# Epoch 41/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4248 - val_loss: 0.4211
# Epoch 42/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.4221 - val_loss: 0.4185
# Epoch 43/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4195 - val_loss: 0.4159
# Epoch 44/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4169 - val_loss: 0.4133
# Epoch 45/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4144 - val_loss: 0.4108
# Epoch 46/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.4119 - val_loss: 0.4083
# Epoch 47/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.4095 - val_loss: 0.4059
# Epoch 48/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.4071 - val_loss: 0.4035
# Epoch 49/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4047 - val_loss: 0.4011
# Epoch 50/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4023 - val_loss: 0.3988
# Epoch 51/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.4000 - val_loss: 0.3965
# Epoch 52/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3978 - val_loss: 0.3943
# Epoch 53/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.3956 - val_loss: 0.3921
# Epoch 54/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.3934 - val_loss: 0.3899
# Epoch 55/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.3912 - val_loss: 0.3878
# Epoch 56/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3891 - val_loss: 0.3857
# Epoch 57/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3871 - val_loss: 0.3837
# Epoch 58/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3850 - val_loss: 0.3817
# Epoch 59/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.3831 - val_loss: 0.3797
# Epoch 60/100
# 235/235 [==============================] - 3s 15ms/step - loss: 0.3811 - val_loss: 0.3778
# Epoch 61/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3792 - val_loss: 0.3759
# Epoch 62/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3773 - val_loss: 0.3741
# Epoch 63/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.3755 - val_loss: 0.3723
# Epoch 64/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3737 - val_loss: 0.3705
# Epoch 65/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3719 - val_loss: 0.3688
# Epoch 66/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.3702 - val_loss: 0.3671
# Epoch 67/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3685 - val_loss: 0.3654
# Epoch 68/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.3669 - val_loss: 0.3638
# Epoch 69/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.3652 - val_loss: 0.3622
# Epoch 70/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3636 - val_loss: 0.3606
# Epoch 71/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3621 - val_loss: 0.3591
# Epoch 72/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.3606 - val_loss: 0.3576
# Epoch 73/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.3591 - val_loss: 0.3561
# Epoch 74/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.3576 - val_loss: 0.3547
# Epoch 75/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3562 - val_loss: 0.3533
# Epoch 76/100
# 235/235 [==============================] - 4s 16ms/step - loss: 0.3548 - val_loss: 0.3519
# Epoch 77/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3534 - val_loss: 0.3506
# Epoch 78/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3521 - val_loss: 0.3492
# Epoch 79/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.3508 - val_loss: 0.3480
# Epoch 80/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.3495 - val_loss: 0.3467
# Epoch 81/100
# 235/235 [==============================] - 4s 15ms/step - loss: 0.3482 - val_loss: 0.3455
# Epoch 82/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.3470 - val_loss: 0.3443
# Epoch 83/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3458 - val_loss: 0.3431
# Epoch 84/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.3446 - val_loss: 0.3420
# Epoch 85/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.3435 - val_loss: 0.3408
# Epoch 86/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3424 - val_loss: 0.3397
# Epoch 87/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.3413 - val_loss: 0.3387
# Epoch 88/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3402 - val_loss: 0.3376
# Epoch 89/100
# 235/235 [==============================] - 4s 18ms/step - loss: 0.3391 - val_loss: 0.3366
# Epoch 90/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3381 - val_loss: 0.3356
# Epoch 91/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3371 - val_loss: 0.3346
# Epoch 92/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3361 - val_loss: 0.3336
# Epoch 93/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.3352 - val_loss: 0.3327
# Epoch 94/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3342 - val_loss: 0.3318
# Epoch 95/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.3333 - val_loss: 0.3309
# Epoch 96/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3324 - val_loss: 0.3300
# Epoch 97/100
# 235/235 [==============================] - 4s 17ms/step - loss: 0.3315 - val_loss: 0.3291
# Epoch 98/100
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3307 - val_loss: 0.3283
# Epoch 99/100
# 235/235 [==============================] - 3s 13ms/step - loss: 0.3298 - val_loss: 0.3274
# Epoch 100/100
# 235/235 [==============================] - 3s 12ms/step - loss: 0.3290 - val_loss: 0.3266
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 2ms/step

# %%
from keras.layers import Input, Dense
from keras.models import Model, Sequential

# this is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# this is our input placeholder
input_img = Input(shape=(784,))
input_dim = x_train.shape[1]


autoencoder = Sequential()

# Encoder Layers
autoencoder.add(Dense(4 * encoding_dim, input_shape=(input_dim,), activation='relu'))
autoencoder.add(Dense(2 * encoding_dim, activation='relu'))

# Decoder Layers
autoencoder.add(Dense(2 * encoding_dim, activation='relu'))
autoencoder.add(Dense(4 * encoding_dim, activation='relu'))
autoencoder.add(Dense(input_dim, activation='sigmoid'))

autoencoder.summary()

autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')


history = autoencoder.fit(x_train, x_train,
                epochs=20,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Plot training and validation losses
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


num_images = 10
np.random.seed(42)
random_test_images = np.random.randint(x_test.shape[0], size=num_images)

encoded_imgs = encoder.predict(x_test)
decoded_imgs = autoencoder.predict(x_test)
plt.figure(figsize=(18, 4))

for i, image_idx in enumerate(random_test_images):
    # plot original image
    ax = plt.subplot(3, num_images, i + 1)
    plt.imshow(x_test[image_idx].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # plot encoded image
    ax = plt.subplot(3, num_images, num_images + i + 1)
    plt.imshow(encoded_imgs[image_idx].reshape(8, 4))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # plot reconstructed image
    ax = plt.subplot(3, num_images, 2*num_images + i + 1)
    plt.imshow(decoded_imgs[image_idx].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 128)               100480
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 128)               8320
#
#  dense_8 (Dense)             (None, 784)               101136
#
# =================================================================
# Total params: 222352 (868.56 KB)
# Trainable params: 222352 (868.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 235/235 [==============================] - 7s 23ms/step - loss: 0.6927 - val_loss: 0.6926
# Epoch 2/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6926 - val_loss: 0.6925
# Epoch 3/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6925 - val_loss: 0.6924
# Epoch 4/20
# 235/235 [==============================] - 5s 23ms/step - loss: 0.6924 - val_loss: 0.6923
# Epoch 5/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6923 - val_loss: 0.6922
# Epoch 6/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6922 - val_loss: 0.6921
# Epoch 7/20
# 235/235 [==============================] - 5s 23ms/step - loss: 0.6921 - val_loss: 0.6920
# Epoch 8/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6920 - val_loss: 0.6919
# Epoch 9/20
# 235/235 [==============================] - 5s 20ms/step - loss: 0.6919 - val_loss: 0.6918
# Epoch 10/20
# 235/235 [==============================] - 5s 20ms/step - loss: 0.6918 - val_loss: 0.6917
# Epoch 11/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6917 - val_loss: 0.6916
# Epoch 12/20
# 235/235 [==============================] - 5s 22ms/step - loss: 0.6916 - val_loss: 0.6915
# Epoch 13/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6915 - val_loss: 0.6914
# Epoch 14/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6914 - val_loss: 0.6913
# Epoch 15/20
# 235/235 [==============================] - 5s 22ms/step - loss: 0.6913 - val_loss: 0.6912
# Epoch 16/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6912 - val_loss: 0.6911
# Epoch 17/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6911 - val_loss: 0.6910
# Epoch 18/20
# 235/235 [==============================] - 5s 23ms/step - loss: 0.6910 - val_loss: 0.6909
# Epoch 19/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6909 - val_loss: 0.6908
# Epoch 20/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6908 - val_loss: 0.6907
# 313/313 [==============================] - 2s 5ms/step
# 313/313 [==============================] - 1s 2ms/step

# %%
from keras.layers import Input, Dense
from keras.models import Model

# this is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# this is our input placeholder
input_img = Input(shape=(784,))
input_dim = x_train.shape[1]


autoencoder = Sequential()

# Encoder Layers
autoencoder.add(Dense(2 * encoding_dim, input_shape=(input_dim,), activation='relu'))
autoencoder.add(Dense(encoding_dim, activation='relu'))

# Decoder Layers
autoencoder.add(Dense(2 * encoding_dim, activation='relu'))
autoencoder.add(Dense(input_dim, activation='sigmoid'))

autoencoder.summary()

autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')


history = autoencoder.fit(x_train, x_train,
                epochs=20,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Plot training and validation losses
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


num_images = 10
np.random.seed(42)
random_test_images = np.random.randint(x_test.shape[0], size=num_images)

encoded_imgs = encoder.predict(x_test)
decoded_imgs = autoencoder.predict(x_test)

plt.figure(figsize=(18, 4))

for i, image_idx in enumerate(random_test_images):
    # plot original image
    ax = plt.subplot(3, num_images, i + 1)
    plt.imshow(x_test[image_idx].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # plot encoded image
    ax = plt.subplot(3, num_images, num_images + i + 1)
    plt.imshow(encoded_imgs[image_idx].reshape(8, 4))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # plot reconstructed image
    ax = plt.subplot(3, num_images, 2*num_images + i + 1)
    plt.imshow(decoded_imgs[image_idx].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 64)                50240
#
#  dense_10 (Dense)            (None, 32)                2080
#
#  dense_11 (Dense)            (None, 64)                2112
#
#  dense_12 (Dense)            (None, 784)               50960
#
# =================================================================
# Total params: 105392 (411.69 KB)
# Trainable params: 105392 (411.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 235/235 [==============================] - 4s 14ms/step - loss: 0.6912 - val_loss: 0.6911
# Epoch 2/20
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6910 - val_loss: 0.6910
# Epoch 3/20
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6909 - val_loss: 0.6908
# Epoch 4/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6907 - val_loss: 0.6906
# Epoch 5/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6905 - val_loss: 0.6904
# Epoch 6/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6903 - val_loss: 0.6903
# Epoch 7/20
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6902 - val_loss: 0.6901
# Epoch 8/20
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6900 - val_loss: 0.6899
# Epoch 9/20
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6898 - val_loss: 0.6897
# Epoch 10/20
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6896 - val_loss: 0.6895
# Epoch 11/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6894 - val_loss: 0.6893
# Epoch 12/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6892 - val_loss: 0.6891
# Epoch 13/20
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6890 - val_loss: 0.6890
# Epoch 14/20
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6889 - val_loss: 0.6888
# Epoch 15/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6887 - val_loss: 0.6886
# Epoch 16/20
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6885 - val_loss: 0.6884
# Epoch 17/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6882 - val_loss: 0.6881
# Epoch 18/20
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6880 - val_loss: 0.6879
# Epoch 19/20
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6878 - val_loss: 0.6877
# Epoch 20/20
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6876 - val_loss: 0.6875
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 3ms/step

# %%
from keras.layers import Input, Dense
from keras.models import Model

# this is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# this is our input placeholder
input_img = Input(shape=(784,))
input_dim = x_train.shape[1]


autoencoder = Sequential()

# Encoder Layers
autoencoder.add(Dense(2 * encoding_dim, input_shape=(input_dim,), activation='relu'))

# Decoder Layers
autoencoder.add(Dense(2 * encoding_dim, activation='relu'))
autoencoder.add(Dense(input_dim, activation='sigmoid'))

autoencoder.summary()

autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')


history = autoencoder.fit(x_train, x_train,
                epochs=20,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Plot training and validation losses
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


num_images = 10
np.random.seed(42)
random_test_images = np.random.randint(x_test.shape[0], size=num_images)

encoded_imgs = encoder.predict(x_test)
decoded_imgs = autoencoder.predict(x_test)
plt.figure(figsize=(18, 4))

for i, image_idx in enumerate(random_test_images):
    # plot original image
    ax = plt.subplot(3, num_images, i + 1)
    plt.imshow(x_test[image_idx].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # plot encoded image
    ax = plt.subplot(3, num_images, num_images + i + 1)
    plt.imshow(encoded_imgs[image_idx].reshape(8, 4))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # plot reconstructed image
    ax = plt.subplot(3, num_images, 2*num_images + i + 1)
    plt.imshow(decoded_imgs[image_idx].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 64)                50240
#
#  dense_14 (Dense)            (None, 64)                4160
#
#  dense_15 (Dense)            (None, 784)               50960
#
# =================================================================
# Total params: 105360 (411.56 KB)
# Trainable params: 105360 (411.56 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 235/235 [==============================] - 4s 13ms/step - loss: 0.6948 - val_loss: 0.6947
# Epoch 2/20
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6946 - val_loss: 0.6945
# Epoch 3/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6944 - val_loss: 0.6943
# Epoch 4/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6942 - val_loss: 0.6941
# Epoch 5/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6941 - val_loss: 0.6940
# Epoch 6/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6939 - val_loss: 0.6938
# Epoch 7/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6937 - val_loss: 0.6936
# Epoch 8/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6936 - val_loss: 0.6935
# Epoch 9/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6934 - val_loss: 0.6933
# Epoch 10/20
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6932 - val_loss: 0.6931
# Epoch 11/20
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6931 - val_loss: 0.6930
# Epoch 12/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6929 - val_loss: 0.6928
# Epoch 13/20
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6928 - val_loss: 0.6926
# Epoch 14/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6926 - val_loss: 0.6925
# Epoch 15/20
# 235/235 [==============================] - 4s 18ms/step - loss: 0.6924 - val_loss: 0.6923
# Epoch 16/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6923 - val_loss: 0.6922
# Epoch 17/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6921 - val_loss: 0.6920
# Epoch 18/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6920 - val_loss: 0.6919
# Epoch 19/20
# 235/235 [==============================] - 4s 17ms/step - loss: 0.6918 - val_loss: 0.6917
# Epoch 20/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6917 - val_loss: 0.6915
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 2ms/step

# %%
from keras.layers import Input, Dense
from keras.models import Model
# this is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder = Model(input_img, decoded)
# this model maps an input to its encoded representation
encoder = Model(input_img, encoded)

# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(encoding_dim,))
# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))

autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

history = autoencoder.fit(x_train, x_train,
                epochs=20,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Plot training and validation losses
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

num_images = 10
np.random.seed(42)
random_test_images = np.random.randint(x_test.shape[0], size=num_images)

encoded_imgs = encoder.predict(x_test)
decoded_imgs = autoencoder.predict(x_test)
plt.figure(figsize=(18, 4))

for i, image_idx in enumerate(random_test_images):
    # plot original image
    ax = plt.subplot(3, num_images, i + 1)
    plt.imshow(x_test[image_idx].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # plot encoded image
    ax = plt.subplot(3, num_images, num_images + i + 1)
    plt.imshow(encoded_imgs[image_idx].reshape(8, 4))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # plot reconstructed image
    ax = plt.subplot(3, num_images, 2*num_images + i + 1)
    plt.imshow(decoded_imgs[image_idx].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Epoch 1/20
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6926 - val_loss: 0.6925
# Epoch 2/20
# 235/235 [==============================] - 2s 10ms/step - loss: 0.6924 - val_loss: 0.6923
# Epoch 3/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6922 - val_loss: 0.6922
# Epoch 4/20
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6921 - val_loss: 0.6920
# Epoch 5/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6919 - val_loss: 0.6918
# Epoch 6/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6917 - val_loss: 0.6917
# Epoch 7/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6916 - val_loss: 0.6915
# Epoch 8/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6914 - val_loss: 0.6913
# Epoch 9/20
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6912 - val_loss: 0.6912
# Epoch 10/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6911 - val_loss: 0.6910
# Epoch 11/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6909 - val_loss: 0.6908
# Epoch 12/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6907 - val_loss: 0.6906
# Epoch 13/20
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6906 - val_loss: 0.6905
# Epoch 14/20
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6904 - val_loss: 0.6903
# Epoch 15/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6902 - val_loss: 0.6901
# Epoch 16/20
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6900 - val_loss: 0.6899
# Epoch 17/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6899 - val_loss: 0.6898
# Epoch 18/20
# 235/235 [==============================] - 4s 16ms/step - loss: 0.6897 - val_loss: 0.6896
# Epoch 19/20
# 235/235 [==============================] - 3s 12ms/step - loss: 0.6895 - val_loss: 0.6894
# Epoch 20/20
# 235/235 [==============================] - 3s 11ms/step - loss: 0.6893 - val_loss: 0.6892
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 1s 2ms/step
